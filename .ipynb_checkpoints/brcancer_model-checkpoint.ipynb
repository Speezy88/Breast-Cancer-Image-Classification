# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib as plt
from torch.utils.data import DataLoader
from sklearn.model_selection import StratifiedKFold
import numpy as np

# %%
class BinaryClassifier(nn.Module):
    def __init__(self, input_dim, hidden_layers):
        super(BinaryClassifier, self).__init__()
        layers = []
        #add fully connected layers with the input dim dividing by two each time the input shape
        output_dim = max(2*input_dim//(3), 1)
        for i in range(hidden_layers):
            i += 1
            layers.append(nn.Linear(input_dim,output_dim))
            layers.append(nn.ReLU())
            input_dim = output_dim
            output_dim = max(int(input_dim//(1.1*i)), 1)
        #add final layer with sigmiod output and final linear layer
        layers.append(nn.Linear(input_dim,1))
        #layers.append(nn.Sigmoid())

        #create a Seqeuntial implementation, no additional layers but provides one line to run through all layers
        self.network = nn.Sequential(*layers)
    
    def forward(self, x):
        #apply the neural net
        return self.network(x)

# %%
#input shape is not correct
input_shape = 30
hidden_layers = 5
model_1 = BinaryClassifier(input_shape, hidden_layers)

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from torch.utils.data import DataLoader, TensorDataset

# %%
def dataset_to_numpy(dataset: TensorDataset):
    X, y = dataset.tensors
    # Ensure on CPU and detached from computation graph
    X_np = X.detach().numpy()
    y_np = y.detach().numpy()
    return X_np, y_np

# %%
def load_data():
    # Read data
    df = pd.read_csv('br_cancer_normalized.csv', encoding='latin-1')

    # Separate features and labels
    X = df.drop(columns=['Diagnosis']).to_numpy()
    y = df['Diagnosis'].to_numpy()
    return X, y

# %%
#import whatever data loader function is needed
#should output train dataloader and test dataloader  as the full train and test datasets
X_np, y_np = load_data()
print(X_np.shape, y_np.shape)
# Out:
# (569, 30) (569,)

# %%
# Count positives and negatives
num_pos = (y_np == 1).sum().item()
num_neg = (y_np == 0).sum().item()

# Compute base pos_weight
base_pos_weight = num_neg / num_pos

# Increase penalty for missing a 1 by 20%
pos_weight_value = torch.tensor(base_pos_weight*2)

# %%
optimizer = optim.Adam(model_1.parameters(), lr=1e-3)
loss_fn = nn.BCEWithLogitsLoss(pos_weight=pos_weight_value * 1.2)

# %%
def visualize_prediction_distribution(model, dataloader, threshold=0.5):
    """
    Visualize the percentage of predicted 0s and 1s from a binary classifier.
    
    Args:
        model: Trained PyTorch model
        dataloader: DataLoader containing your dataset
        threshold: Decision threshold for classification (default=0.5)
        device: "cpu" or "cuda"
    """
    model.eval()
    preds = []
    
    with torch.no_grad():
        for batch_X, _ in dataloader:
            outputs = model(batch_X).squeeze()
            
            # If model ends with Sigmoid
            if outputs.dim() == 0:
                outputs = outputs.unsqueeze(0)
            
            predicted = (outputs >= threshold).int().cpu().numpy()
            preds.extend(predicted)
    
    preds = np.array(preds)
    total = len(preds)
    percent_0 = (preds == 0).sum() / total * 100
    percent_1 = (preds == 1).sum() / total * 100
    print(percent_0, "this is percent 0")
    # # Bar plot
    # plt.bar(["Predicted 0", "Predicted 1"], [percent_0, percent_1], color=["skyblue", "salmon"])
    # plt.ylabel("Percentage (%)")
    # plt.title("Prediction Distribution")
    # plt.show()
    
    print(f"Predicted 0: {percent_0:.2f}%")
    print(f"Predicted 1: {percent_1:.2f}%")

# %%
from statistics import mean, stdev
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
from sklearn import datasets

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, Subset
from sklearn.model_selection import StratifiedKFold
import copy

def test(model, data, criterion):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for batch_X, batch_y in data:
            batch_y = batch_y.unsqueeze(1)
            logits = model(batch_X)
            loss = criterion(logits, batch_y)
            test_loss += loss.item() * batch_X.size(0)

            preds = (torch.sigmoid(logits) >= 0.5).float()
            correct += (preds == batch_y).sum().item()
            total += batch_y.size(0)
    
    avg_loss = test_loss / total
    accuracy = correct / total
    print(f"Test Loss: {avg_loss:.4f} | Test Acc: {accuracy:.4f}")
    return avg_loss, accuracy
    

def train_with_stratified_kfold(X, y, model_fn, input_shape, hidden_layers, batch_size=32, lr=1e-3, k_folds=5, num_epochs=300):
    # Wrap into dataset
    dataset = TensorDataset(torch.tensor(X, dtype=torch.float32),
                            torch.tensor(y, dtype=torch.float32))
    
    skf = StratifiedKFold(n_splits=k_folds, shuffle=True)
    all_fold_results = []
    models = []
    for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
        print(f"\n--- Fold {fold+1} ---")

        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
     # fresh model for each fold
        cur_model = BinaryClassifier(30,5)
        criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight_value * 1.05)
        optimizer = optim.Adam(cur_model.parameters(), lr=lr)

        for epoch in range(num_epochs):
            cur_model.train()
            epoch_loss = 0.0
            correct = 0
            total = 0

            for batch_X, batch_y in train_loader:
                optimizer.zero_grad()
                outputs = cur_model(batch_X).squeeze()
                loss = criterion(outputs, batch_y)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item() * batch_X.size(0)
                preds = (torch.sigmoid(outputs) >= 0.5).float()
                correct += (preds == batch_y).sum().item()
                total += batch_y.size(0)

            train_acc = correct / total
            train_loss = epoch_loss / total
            print(f"Epoch {epoch+1}: Train Loss {train_loss:.4f} | Train Acc {train_acc:.4f}")

        avg_loss, accuracy = test(cur_model, val_loader, criterion)
        all_fold_results.append((avg_loss, accuracy))
        models.append(cur_model)
        visualize_prediction_distribution(cur_model, val_loader)

    
    return all_fold_results , models

# %%
fold_results, models = train_with_stratified_kfold(X_np,y_np,model_1,30,5)
# Out:
# --- Fold 1 ---
# Epoch 1: Train Loss 1.2935 | Train Acc 0.3736
# Epoch 2: Train Loss 1.2840 | Train Acc 0.3736
# Epoch 3: Train Loss 1.2720 | Train Acc 0.3736
# Epoch 4: Train Loss 1.2554 | Train Acc 0.3736
# Epoch 5: Train Loss 1.2286 | Train Acc 0.3736
# Epoch 6: Train Loss 1.1801 | Train Acc 0.3736
# Epoch 7: Train Loss 1.1223 | Train Acc 0.3736
# Epoch 8: Train Loss 1.0679 | Train Acc 0.3736
# Epoch 9: Train Loss 1.0106 | Train Acc 0.3736
# Epoch 10: Train Loss 0.9432 | Train Acc 0.3736
# Epoch 11: Train Loss 0.8718 | Train Acc 0.3736
# Epoch 12: Train Loss 0.7974 | Train Acc 0.3736
# Epoch 13: Train Loss 0.7382 | Train Acc 0.3736
# Epoch 14: Train Loss 0.6624 | Train Acc 0.5429
# Epoch 15: Train Loss 0.5834 | Train Acc 0.8440
# Epoch 16: Train Loss 0.5277 | Train Acc 0.8593
# Epoch 17: Train Loss 0.5022 | Train Acc 0.8945
# Epoch 18: Train Loss 0.4899 | Train Acc 0.8835
# Epoch 19: Train Loss 0.4787 | Train Acc 0.9121
# Epoch 20: Train Loss 0.4674 | Train Acc 0.9033
# Epoch 21: Train Loss 0.4607 | Train Acc 0.9231
# Epoch 22: Train Loss 0.4581 | Train Acc 0.9055
# Epoch 23: Train Loss 0.4459 | Train Acc 0.9077
# Epoch 24: Train Loss 0.4371 | Train Acc 0.9297
# Epoch 25: Train Loss 0.4295 | Train Acc 0.9143
# Epoch 26: Train Loss 0.4221 | Train Acc 0.9319
# Epoch 27: Train Loss 0.4139 | Train Acc 0.9209
# Epoch 28: Train Loss 0.4163 | Train Acc 0.9297
# Epoch 29: Train Loss 0.4043 | Train Acc 0.9297
# Epoch 30: Train Loss 0.3996 | Train Acc 0.9341
# Epoch 31: Train Loss 0.3909 | Train Acc 0.9319
# Epoch 32: Train Loss 0.3826 | Train Acc 0.9407
# Epoch 33: Train Loss 0.3763 | Train Acc 0.9385
# Epoch 34: Train Loss 0.3723 | Train Acc 0.9385
# Epoch 35: Train Loss 0.3666 | Train Acc 0.9473
# Epoch 36: Train Loss 0.3626 | Train Acc 0.9495
# Epoch 37: Train Loss 0.3616 | Train Acc 0.9473
# Epoch 38: Train Loss 0.3558 | Train Acc 0.9363
# Epoch 39: Train Loss 0.3513 | Train Acc 0.9582
# Epoch 40: Train Loss 0.3413 | Train Acc 0.9473
# Epoch 41: Train Loss 0.3370 | Train Acc 0.9538
# Epoch 42: Train Loss 0.3334 | Train Acc 0.9516
# Epoch 43: Train Loss 0.3305 | Train Acc 0.9473
# Epoch 44: Train Loss 0.3267 | Train Acc 0.9582
# Epoch 45: Train Loss 0.3267 | Train Acc 0.9516
# Epoch 46: Train Loss 0.3175 | Train Acc 0.9538
# Epoch 47: Train Loss 0.3173 | Train Acc 0.9516
# Epoch 48: Train Loss 0.3129 | Train Acc 0.9604
# Epoch 49: Train Loss 0.3140 | Train Acc 0.9516
# Epoch 50: Train Loss 0.3085 | Train Acc 0.9648
# Epoch 51: Train Loss 0.3074 | Train Acc 0.9648
# Epoch 52: Train Loss 0.3020 | Train Acc 0.9626
# Epoch 53: Train Loss 0.2982 | Train Acc 0.9626
# Epoch 54: Train Loss 0.2963 | Train Acc 0.9626
# Epoch 55: Train Loss 0.2943 | Train Acc 0.9692
# Epoch 56: Train Loss 0.2919 | Train Acc 0.9626
# Epoch 57: Train Loss 0.2906 | Train Acc 0.9714
# Epoch 58: Train Loss 0.2862 | Train Acc 0.9604
# Epoch 59: Train Loss 0.2860 | Train Acc 0.9692
# Epoch 60: Train Loss 0.2824 | Train Acc 0.9626
# Epoch 61: Train Loss 0.2809 | Train Acc 0.9714
# Epoch 62: Train Loss 0.2798 | Train Acc 0.9582
# Epoch 63: Train Loss 0.2767 | Train Acc 0.9714
# Epoch 64: Train Loss 0.2743 | Train Acc 0.9714
# Epoch 65: Train Loss 0.2699 | Train Acc 0.9692
# Epoch 66: Train Loss 0.2676 | Train Acc 0.9714
# Epoch 67: Train Loss 0.2710 | Train Acc 0.9736
# Epoch 68: Train Loss 0.2705 | Train Acc 0.9692
# Epoch 69: Train Loss 0.2654 | Train Acc 0.9626
# Epoch 70: Train Loss 0.2626 | Train Acc 0.9758
# Epoch 71: Train Loss 0.2598 | Train Acc 0.9692
# Epoch 72: Train Loss 0.2558 | Train Acc 0.9714
# Epoch 73: Train Loss 0.2571 | Train Acc 0.9714
# Epoch 74: Train Loss 0.2535 | Train Acc 0.9736
# Epoch 75: Train Loss 0.2506 | Train Acc 0.9714
# Epoch 76: Train Loss 0.2496 | Train Acc 0.9714
# Epoch 77: Train Loss 0.2463 | Train Acc 0.9736
# Epoch 78: Train Loss 0.2490 | Train Acc 0.9736
# Epoch 79: Train Loss 0.2483 | Train Acc 0.9714
# Epoch 80: Train Loss 0.2431 | Train Acc 0.9714
# Epoch 81: Train Loss 0.2396 | Train Acc 0.9758
# Epoch 82: Train Loss 0.2415 | Train Acc 0.9692
# Epoch 83: Train Loss 0.2391 | Train Acc 0.9780
# Epoch 84: Train Loss 0.2451 | Train Acc 0.9604
# Epoch 85: Train Loss 0.2342 | Train Acc 0.9648
# Epoch 86: Train Loss 0.2360 | Train Acc 0.9758
# Epoch 87: Train Loss 0.2330 | Train Acc 0.9648
# Epoch 88: Train Loss 0.2274 | Train Acc 0.9736
# Epoch 89: Train Loss 0.2279 | Train Acc 0.9736
# Epoch 90: Train Loss 0.2321 | Train Acc 0.9604
# Epoch 91: Train Loss 0.2269 | Train Acc 0.9736
# Epoch 92: Train Loss 0.2219 | Train Acc 0.9714
# Epoch 93: Train Loss 0.2278 | Train Acc 0.9736
# Epoch 94: Train Loss 0.2195 | Train Acc 0.9714
# Epoch 95: Train Loss 0.2263 | Train Acc 0.9736
# Epoch 96: Train Loss 0.2187 | Train Acc 0.9736
# Epoch 97: Train Loss 0.2143 | Train Acc 0.9736
# Epoch 98: Train Loss 0.2173 | Train Acc 0.9736
# Epoch 99: Train Loss 0.2105 | Train Acc 0.9758
# Epoch 100: Train Loss 0.2141 | Train Acc 0.9758
# Epoch 101: Train Loss 0.2150 | Train Acc 0.9824
# Epoch 102: Train Loss 0.2084 | Train Acc 0.9736
# Epoch 103: Train Loss 0.2126 | Train Acc 0.9736
# Epoch 104: Train Loss 0.2094 | Train Acc 0.9780
# Epoch 105: Train Loss 0.2083 | Train Acc 0.9736
# Epoch 106: Train Loss 0.2050 | Train Acc 0.9780
# Epoch 107: Train Loss 0.2068 | Train Acc 0.9692
# Epoch 108: Train Loss 0.1990 | Train Acc 0.9758
# Epoch 109: Train Loss 0.1994 | Train Acc 0.9758
# Epoch 110: Train Loss 0.2011 | Train Acc 0.9736
# Epoch 111: Train Loss 0.1995 | Train Acc 0.9780
# Epoch 112: Train Loss 0.1978 | Train Acc 0.9736
# Epoch 113: Train Loss 0.2039 | Train Acc 0.9802
# Epoch 114: Train Loss 0.1970 | Train Acc 0.9714
# Epoch 115: Train Loss 0.2045 | Train Acc 0.9758
# Epoch 116: Train Loss 0.1987 | Train Acc 0.9692
# Epoch 117: Train Loss 0.2066 | Train Acc 0.9802
# Epoch 118: Train Loss 0.1953 | Train Acc 0.9714
# Epoch 119: Train Loss 0.2060 | Train Acc 0.9758
# Epoch 120: Train Loss 0.1924 | Train Acc 0.9736
# Epoch 121: Train Loss 0.1898 | Train Acc 0.9780
# Epoch 122: Train Loss 0.2254 | Train Acc 0.9604
# Epoch 123: Train Loss 0.1936 | Train Acc 0.9780
# Epoch 124: Train Loss 0.1881 | Train Acc 0.9736
# Epoch 125: Train Loss 0.1943 | Train Acc 0.9714
# Epoch 126: Train Loss 0.1975 | Train Acc 0.9648
# Epoch 127: Train Loss 0.1922 | Train Acc 0.9824
# Epoch 128: Train Loss 0.1833 | Train Acc 0.9736
# Epoch 129: Train Loss 0.1947 | Train Acc 0.9780
# Epoch 130: Train Loss 0.1839 | Train Acc 0.9714
# Epoch 131: Train Loss 0.1799 | Train Acc 0.9824
# Epoch 132: Train Loss 0.1876 | Train Acc 0.9626
# Epoch 133: Train Loss 0.1814 | Train Acc 0.9802
# Epoch 134: Train Loss 0.1865 | Train Acc 0.9736
# Epoch 135: Train Loss 0.1809 | Train Acc 0.9736
# Epoch 136: Train Loss 0.1751 | Train Acc 0.9758
# Epoch 137: Train Loss 0.1751 | Train Acc 0.9780
# Epoch 138: Train Loss 0.1762 | Train Acc 0.9802
# Epoch 139: Train Loss 0.1792 | Train Acc 0.9736
# Epoch 140: Train Loss 0.1719 | Train Acc 0.9758
# Epoch 141: Train Loss 0.1710 | Train Acc 0.9758
# Epoch 142: Train Loss 0.1707 | Train Acc 0.9736
# Epoch 143: Train Loss 0.1742 | Train Acc 0.9868
# Epoch 144: Train Loss 0.1712 | Train Acc 0.9758
# Epoch 145: Train Loss 0.1676 | Train Acc 0.9824
# Epoch 146: Train Loss 0.1670 | Train Acc 0.9758
# Epoch 147: Train Loss 0.1691 | Train Acc 0.9824
# Epoch 148: Train Loss 0.1693 | Train Acc 0.9736
# Epoch 149: Train Loss 0.1760 | Train Acc 0.9626
# Epoch 150: Train Loss 0.1712 | Train Acc 0.9824
# Epoch 151: Train Loss 0.1715 | Train Acc 0.9780
# Epoch 152: Train Loss 0.1725 | Train Acc 0.9714
# Epoch 153: Train Loss 0.1697 | Train Acc 0.9846
# Epoch 154: Train Loss 0.1723 | Train Acc 0.9736
# Epoch 155: Train Loss 0.1667 | Train Acc 0.9824
# Epoch 156: Train Loss 0.1645 | Train Acc 0.9758
# Epoch 157: Train Loss 0.1748 | Train Acc 0.9824
# Epoch 158: Train Loss 0.1662 | Train Acc 0.9758
# Epoch 159: Train Loss 0.1622 | Train Acc 0.9780
# Epoch 160: Train Loss 0.1624 | Train Acc 0.9758
# Epoch 161: Train Loss 0.1635 | Train Acc 0.9758
# Epoch 162: Train Loss 0.1628 | Train Acc 0.9846
# Epoch 163: Train Loss 0.1618 | Train Acc 0.9736
# Epoch 164: Train Loss 0.1618 | Train Acc 0.9824
# Epoch 165: Train Loss 0.1527 | Train Acc 0.9802
# Epoch 166: Train Loss 0.1568 | Train Acc 0.9824
# Epoch 167: Train Loss 0.1580 | Train Acc 0.9780
# Epoch 168: Train Loss 0.1549 | Train Acc 0.9824
# Epoch 169: Train Loss 0.1545 | Train Acc 0.9758
# Epoch 170: Train Loss 0.1510 | Train Acc 0.9802
# Epoch 171: Train Loss 0.1543 | Train Acc 0.9802
# Epoch 172: Train Loss 0.1562 | Train Acc 0.9802
# Epoch 173: Train Loss 0.1685 | Train Acc 0.9802
# Epoch 174: Train Loss 0.1547 | Train Acc 0.9802
# Epoch 175: Train Loss 0.1559 | Train Acc 0.9780
# Epoch 176: Train Loss 0.1710 | Train Acc 0.9758
# Epoch 177: Train Loss 0.1462 | Train Acc 0.9824
# Epoch 178: Train Loss 0.1571 | Train Acc 0.9758
# Epoch 179: Train Loss 0.1535 | Train Acc 0.9780
# Epoch 180: Train Loss 0.1507 | Train Acc 0.9758
# Epoch 181: Train Loss 0.1440 | Train Acc 0.9824
# Epoch 182: Train Loss 0.1485 | Train Acc 0.9780
# Epoch 183: Train Loss 0.1490 | Train Acc 0.9780
# Epoch 184: Train Loss 0.1444 | Train Acc 0.9780
# Epoch 185: Train Loss 0.1517 | Train Acc 0.9802
# Epoch 186: Train Loss 0.1442 | Train Acc 0.9802
# Epoch 187: Train Loss 0.1430 | Train Acc 0.9824
# Epoch 188: Train Loss 0.1427 | Train Acc 0.9780
# Epoch 189: Train Loss 0.1415 | Train Acc 0.9824
# Epoch 190: Train Loss 0.1458 | Train Acc 0.9780
# Epoch 191: Train Loss 0.1501 | Train Acc 0.9824
# Epoch 192: Train Loss 0.1413 | Train Acc 0.9802
# Epoch 193: Train Loss 0.1591 | Train Acc 0.9846
# Epoch 194: Train Loss 0.1470 | Train Acc 0.9692
# Epoch 195: Train Loss 0.1444 | Train Acc 0.9802
# Epoch 196: Train Loss 0.1406 | Train Acc 0.9780
# Epoch 197: Train Loss 0.1380 | Train Acc 0.9802
# Epoch 198: Train Loss 0.1379 | Train Acc 0.9802
# Epoch 199: Train Loss 0.1417 | Train Acc 0.9824
# Epoch 200: Train Loss 0.1500 | Train Acc 0.9670
# Epoch 201: Train Loss 0.1421 | Train Acc 0.9824
# Epoch 202: Train Loss 0.1419 | Train Acc 0.9780
# Epoch 203: Train Loss 0.1362 | Train Acc 0.9824
# Epoch 204: Train Loss 0.1382 | Train Acc 0.9780
# Epoch 205: Train Loss 0.1334 | Train Acc 0.9802
# Epoch 206: Train Loss 0.1374 | Train Acc 0.9714
# Epoch 207: Train Loss 0.1379 | Train Acc 0.9824
# Epoch 208: Train Loss 0.1330 | Train Acc 0.9780
# Epoch 209: Train Loss 0.1335 | Train Acc 0.9802
# Epoch 210: Train Loss 0.1323 | Train Acc 0.9824
# Epoch 211: Train Loss 0.1352 | Train Acc 0.9802
# Epoch 212: Train Loss 0.1300 | Train Acc 0.9824
# Epoch 213: Train Loss 0.1318 | Train Acc 0.9780
# Epoch 214: Train Loss 0.1421 | Train Acc 0.9846
# Epoch 215: Train Loss 0.1416 | Train Acc 0.9758
# Epoch 216: Train Loss 0.1421 | Train Acc 0.9802
# Epoch 217: Train Loss 0.1353 | Train Acc 0.9824
# Epoch 218: Train Loss 0.1606 | Train Acc 0.9824
# Epoch 219: Train Loss 0.1395 | Train Acc 0.9736
# Epoch 220: Train Loss 0.1340 | Train Acc 0.9802
# Epoch 221: Train Loss 0.1331 | Train Acc 0.9824
# Epoch 222: Train Loss 0.1692 | Train Acc 0.9495
# Epoch 223: Train Loss 0.1441 | Train Acc 0.9824
# Epoch 224: Train Loss 0.1299 | Train Acc 0.9780
# Epoch 225: Train Loss 0.1280 | Train Acc 0.9824
# Epoch 226: Train Loss 0.1267 | Train Acc 0.9824
# Epoch 227: Train Loss 0.1286 | Train Acc 0.9824
# Epoch 228: Train Loss 0.1440 | Train Acc 0.9670
# Epoch 229: Train Loss 0.1359 | Train Acc 0.9714
# Epoch 230: Train Loss 0.1298 | Train Acc 0.9780
# Epoch 231: Train Loss 0.1281 | Train Acc 0.9824
# Epoch 232: Train Loss 0.1254 | Train Acc 0.9758
# Epoch 233: Train Loss 0.1232 | Train Acc 0.9802
# Epoch 234: Train Loss 0.1239 | Train Acc 0.9824
# Epoch 235: Train Loss 0.1432 | Train Acc 0.9648
# Epoch 236: Train Loss 0.1262 | Train Acc 0.9824
# Epoch 237: Train Loss 0.1341 | Train Acc 0.9714
# Epoch 238: Train Loss 0.1273 | Train Acc 0.9824
# Epoch 239: Train Loss 0.1247 | Train Acc 0.9758
# Epoch 240: Train Loss 0.1268 | Train Acc 0.9780
# Epoch 241: Train Loss 0.1231 | Train Acc 0.9802
# Epoch 242: Train Loss 0.1223 | Train Acc 0.9802
# Epoch 243: Train Loss 0.1211 | Train Acc 0.9802
# Epoch 244: Train Loss 0.1247 | Train Acc 0.9824
# Epoch 245: Train Loss 0.1225 | Train Acc 0.9802
# Epoch 246: Train Loss 0.1306 | Train Acc 0.9758
# Epoch 247: Train Loss 0.1232 | Train Acc 0.9846
# Epoch 248: Train Loss 0.1265 | Train Acc 0.9736
# Epoch 249: Train Loss 0.1215 | Train Acc 0.9802
# Epoch 250: Train Loss 0.1183 | Train Acc 0.9824
# Epoch 251: Train Loss 0.1211 | Train Acc 0.9868
# Epoch 252: Train Loss 0.1432 | Train Acc 0.9648
# Epoch 253: Train Loss 0.1501 | Train Acc 0.9648
# Epoch 254: Train Loss 0.1272 | Train Acc 0.9780
# Epoch 255: Train Loss 0.1373 | Train Acc 0.9626
# Epoch 256: Train Loss 0.1347 | Train Acc 0.9868
# Epoch 257: Train Loss 0.1308 | Train Acc 0.9758
# Epoch 258: Train Loss 0.1170 | Train Acc 0.9824
# Epoch 259: Train Loss 0.1185 | Train Acc 0.9780
# Epoch 260: Train Loss 0.1163 | Train Acc 0.9824
# Epoch 261: Train Loss 0.1201 | Train Acc 0.9846
# Epoch 262: Train Loss 0.1313 | Train Acc 0.9692
# Epoch 263: Train Loss 0.1161 | Train Acc 0.9846
# Epoch 264: Train Loss 0.1157 | Train Acc 0.9824
# Epoch 265: Train Loss 0.1218 | Train Acc 0.9824
# Epoch 266: Train Loss 0.1147 | Train Acc 0.9802
# Epoch 267: Train Loss 0.1252 | Train Acc 0.9846
# Epoch 268: Train Loss 0.1205 | Train Acc 0.9758
# Epoch 269: Train Loss 0.1243 | Train Acc 0.9868
# Epoch 270: Train Loss 0.1233 | Train Acc 0.9758
# Epoch 271: Train Loss 0.1232 | Train Acc 0.9846
# Epoch 272: Train Loss 0.1145 | Train Acc 0.9824
# Epoch 273: Train Loss 0.1177 | Train Acc 0.9802
# Epoch 274: Train Loss 0.1163 | Train Acc 0.9846
# Epoch 275: Train Loss 0.1197 | Train Acc 0.9758
# Epoch 276: Train Loss 0.1283 | Train Acc 0.9802
# Epoch 277: Train Loss 0.1136 | Train Acc 0.9802
# Epoch 278: Train Loss 0.1119 | Train Acc 0.9824
# Epoch 279: Train Loss 0.1176 | Train Acc 0.9824
# Epoch 280: Train Loss 0.1144 | Train Acc 0.9802
# Epoch 281: Train Loss 0.1119 | Train Acc 0.9846
# Epoch 282: Train Loss 0.1130 | Train Acc 0.9846
# Epoch 283: Train Loss 0.1175 | Train Acc 0.9780
# Epoch 284: Train Loss 0.1100 | Train Acc 0.9846
# Epoch 285: Train Loss 0.1231 | Train Acc 0.9736
# Epoch 286: Train Loss 0.1869 | Train Acc 0.9758
# Epoch 287: Train Loss 0.1770 | Train Acc 0.9407
# Epoch 288: Train Loss 0.1391 | Train Acc 0.9868
# Epoch 289: Train Loss 0.1188 | Train Acc 0.9780
# Epoch 290: Train Loss 0.1141 | Train Acc 0.9824
# Epoch 291: Train Loss 0.1133 | Train Acc 0.9802
# Epoch 292: Train Loss 0.1110 | Train Acc 0.9824
# Epoch 293: Train Loss 0.1115 | Train Acc 0.9824
# Epoch 294: Train Loss 0.1116 | Train Acc 0.9802
# Epoch 295: Train Loss 0.1170 | Train Acc 0.9824
# Epoch 296: Train Loss 0.1180 | Train Acc 0.9824
# Epoch 297: Train Loss 0.1100 | Train Acc 0.9802
# Epoch 298: Train Loss 0.1157 | Train Acc 0.9802
# Epoch 299: Train Loss 0.1044 | Train Acc 0.9846
# Epoch 300: Train Loss 0.1159 | Train Acc 0.9868
# Test Loss: 0.1856 | Test Acc: 0.9474
# 59.64912280701754 this is percent 0
# Predicted 0: 59.65%
# Predicted 1: 40.35%
#
# --- Fold 2 ---
# Epoch 1: Train Loss 1.3976 | Train Acc 0.6264
# Epoch 2: Train Loss 1.3922 | Train Acc 0.6264
# Epoch 3: Train Loss 1.3869 | Train Acc 0.6264
# Epoch 4: Train Loss 1.3815 | Train Acc 0.6264
# Epoch 5: Train Loss 1.3764 | Train Acc 0.6264
# Epoch 6: Train Loss 1.3716 | Train Acc 0.6264
# Epoch 7: Train Loss 1.3666 | Train Acc 0.6264
# Epoch 8: Train Loss 1.3625 | Train Acc 0.6264
# Epoch 9: Train Loss 1.3579 | Train Acc 0.6264
# Epoch 10: Train Loss 1.3540 | Train Acc 0.6264
# Epoch 11: Train Loss 1.3494 | Train Acc 0.5011
# Epoch 12: Train Loss 1.3452 | Train Acc 0.3736
# Epoch 13: Train Loss 1.3411 | Train Acc 0.3736
# Epoch 14: Train Loss 1.3371 | Train Acc 0.3736
# Epoch 15: Train Loss 1.3333 | Train Acc 0.3736
# Epoch 16: Train Loss 1.3298 | Train Acc 0.3736
# Epoch 17: Train Loss 1.3262 | Train Acc 0.3736
# Epoch 18: Train Loss 1.3225 | Train Acc 0.3736
# Epoch 19: Train Loss 1.3191 | Train Acc 0.3736
# Epoch 20: Train Loss 1.3157 | Train Acc 0.3736
# Epoch 21: Train Loss 1.3123 | Train Acc 0.3736
# Epoch 22: Train Loss 1.3088 | Train Acc 0.3736
# Epoch 23: Train Loss 1.3058 | Train Acc 0.3736
# Epoch 24: Train Loss 1.3029 | Train Acc 0.3736
# Epoch 25: Train Loss 1.3000 | Train Acc 0.3736
# Epoch 26: Train Loss 1.2975 | Train Acc 0.3736
# Epoch 27: Train Loss 1.2950 | Train Acc 0.3736
# Epoch 28: Train Loss 1.2923 | Train Acc 0.3736
# Epoch 29: Train Loss 1.2899 | Train Acc 0.3736
# Epoch 30: Train Loss 1.2876 | Train Acc 0.3736
# Epoch 31: Train Loss 1.2855 | Train Acc 0.3736
# Epoch 32: Train Loss 1.2831 | Train Acc 0.3736
# Epoch 33: Train Loss 1.2807 | Train Acc 0.3736
# Epoch 34: Train Loss 1.2788 | Train Acc 0.3736
# Epoch 35: Train Loss 1.2767 | Train Acc 0.3736
# Epoch 36: Train Loss 1.2746 | Train Acc 0.3736
# Epoch 37: Train Loss 1.2727 | Train Acc 0.3736
# Epoch 38: Train Loss 1.2708 | Train Acc 0.3736
# Epoch 39: Train Loss 1.2691 | Train Acc 0.3736
# Epoch 40: Train Loss 1.2674 | Train Acc 0.3736
# Epoch 41: Train Loss 1.2653 | Train Acc 0.3736
# Epoch 42: Train Loss 1.2637 | Train Acc 0.3736
# Epoch 43: Train Loss 1.2619 | Train Acc 0.3736
# Epoch 44: Train Loss 1.2604 | Train Acc 0.3736
# Epoch 45: Train Loss 1.2589 | Train Acc 0.3736
# Epoch 46: Train Loss 1.2573 | Train Acc 0.3736
# Epoch 47: Train Loss 1.2559 | Train Acc 0.3736
# Epoch 48: Train Loss 1.2547 | Train Acc 0.3736
# Epoch 49: Train Loss 1.2535 | Train Acc 0.3736
# Epoch 50: Train Loss 1.2525 | Train Acc 0.3736
# Epoch 51: Train Loss 1.2513 | Train Acc 0.3736
# Epoch 52: Train Loss 1.2500 | Train Acc 0.3736
# Epoch 53: Train Loss 1.2490 | Train Acc 0.3736
# Epoch 54: Train Loss 1.2480 | Train Acc 0.3736
# Epoch 55: Train Loss 1.2470 | Train Acc 0.3736
# Epoch 56: Train Loss 1.2461 | Train Acc 0.3736
# Epoch 57: Train Loss 1.2450 | Train Acc 0.3736
# Epoch 58: Train Loss 1.2440 | Train Acc 0.3736
# Epoch 59: Train Loss 1.2432 | Train Acc 0.3736
# Epoch 60: Train Loss 1.2423 | Train Acc 0.3736
# Epoch 61: Train Loss 1.2416 | Train Acc 0.3736
# Epoch 62: Train Loss 1.2409 | Train Acc 0.3736
# Epoch 63: Train Loss 1.2403 | Train Acc 0.3736
# Epoch 64: Train Loss 1.2395 | Train Acc 0.3736
# Epoch 65: Train Loss 1.2389 | Train Acc 0.3736
# Epoch 66: Train Loss 1.2382 | Train Acc 0.3736
# Epoch 67: Train Loss 1.2375 | Train Acc 0.3736
# Epoch 68: Train Loss 1.2370 | Train Acc 0.3736
# Epoch 69: Train Loss 1.2365 | Train Acc 0.3736
# Epoch 70: Train Loss 1.2358 | Train Acc 0.3736
# Epoch 71: Train Loss 1.2354 | Train Acc 0.3736
# Epoch 72: Train Loss 1.2346 | Train Acc 0.3736
# Epoch 73: Train Loss 1.2341 | Train Acc 0.3736
# Epoch 74: Train Loss 1.2336 | Train Acc 0.3736
# Epoch 75: Train Loss 1.2332 | Train Acc 0.3736
# Epoch 76: Train Loss 1.2327 | Train Acc 0.3736
# Epoch 77: Train Loss 1.2321 | Train Acc 0.3736
# Epoch 78: Train Loss 1.2318 | Train Acc 0.3736
# Epoch 79: Train Loss 1.2315 | Train Acc 0.3736
# Epoch 80: Train Loss 1.2312 | Train Acc 0.3736
# Epoch 81: Train Loss 1.2306 | Train Acc 0.3736
# Epoch 82: Train Loss 1.2304 | Train Acc 0.3736
# Epoch 83: Train Loss 1.2300 | Train Acc 0.3736
# Epoch 84: Train Loss 1.2298 | Train Acc 0.3736
# Epoch 85: Train Loss 1.2294 | Train Acc 0.3736
# Epoch 86: Train Loss 1.2291 | Train Acc 0.3736
# Epoch 87: Train Loss 1.2289 | Train Acc 0.3736
# Epoch 88: Train Loss 1.2286 | Train Acc 0.3736
# Epoch 89: Train Loss 1.2284 | Train Acc 0.3736
# Epoch 90: Train Loss 1.2282 | Train Acc 0.3736
# Epoch 91: Train Loss 1.2280 | Train Acc 0.3736
# Epoch 92: Train Loss 1.2277 | Train Acc 0.3736
# Epoch 93: Train Loss 1.2275 | Train Acc 0.3736
# Epoch 94: Train Loss 1.2273 | Train Acc 0.3736
# Epoch 95: Train Loss 1.2272 | Train Acc 0.3736
# Epoch 96: Train Loss 1.2271 | Train Acc 0.3736
# Epoch 97: Train Loss 1.2269 | Train Acc 0.3736
# Epoch 98: Train Loss 1.2267 | Train Acc 0.3736
# Epoch 99: Train Loss 1.2266 | Train Acc 0.3736
# Epoch 100: Train Loss 1.2264 | Train Acc 0.3736
# Epoch 101: Train Loss 1.2262 | Train Acc 0.3736
# Epoch 102: Train Loss 1.2261 | Train Acc 0.3736
# Epoch 103: Train Loss 1.2261 | Train Acc 0.3736
# Epoch 104: Train Loss 1.2258 | Train Acc 0.3736
# Epoch 105: Train Loss 1.2257 | Train Acc 0.3736
# Epoch 106: Train Loss 1.2256 | Train Acc 0.3736
# Epoch 107: Train Loss 1.2256 | Train Acc 0.3736
# Epoch 108: Train Loss 1.2254 | Train Acc 0.3736
# Epoch 109: Train Loss 1.2253 | Train Acc 0.3736
# Epoch 110: Train Loss 1.2252 | Train Acc 0.3736
# Epoch 111: Train Loss 1.2251 | Train Acc 0.3736
# Epoch 112: Train Loss 1.2250 | Train Acc 0.3736
# Epoch 113: Train Loss 1.2249 | Train Acc 0.3736
# Epoch 114: Train Loss 1.2248 | Train Acc 0.3736
# Epoch 115: Train Loss 1.2247 | Train Acc 0.3736
# Epoch 116: Train Loss 1.2246 | Train Acc 0.3736
# Epoch 117: Train Loss 1.2245 | Train Acc 0.3736
# Epoch 118: Train Loss 1.2245 | Train Acc 0.3736
# Epoch 119: Train Loss 1.2244 | Train Acc 0.3736
# Epoch 120: Train Loss 1.2244 | Train Acc 0.3736
# Epoch 121: Train Loss 1.2243 | Train Acc 0.3736
# Epoch 122: Train Loss 1.2242 | Train Acc 0.3736
# Epoch 123: Train Loss 1.2242 | Train Acc 0.3736
# Epoch 124: Train Loss 1.2241 | Train Acc 0.3736
# Epoch 125: Train Loss 1.2240 | Train Acc 0.3736
# Epoch 126: Train Loss 1.2240 | Train Acc 0.3736
# Epoch 127: Train Loss 1.2240 | Train Acc 0.3736
# Epoch 128: Train Loss 1.2239 | Train Acc 0.3736
# Epoch 129: Train Loss 1.2239 | Train Acc 0.3736
# Epoch 130: Train Loss 1.2238 | Train Acc 0.3736
# Epoch 131: Train Loss 1.2239 | Train Acc 0.3736
# Epoch 132: Train Loss 1.2237 | Train Acc 0.3736
# Epoch 133: Train Loss 1.2237 | Train Acc 0.3736
# Epoch 134: Train Loss 1.2237 | Train Acc 0.3736
# Epoch 135: Train Loss 1.2236 | Train Acc 0.3736
# Epoch 136: Train Loss 1.2237 | Train Acc 0.3736
# Epoch 137: Train Loss 1.2237 | Train Acc 0.3736
# Epoch 138: Train Loss 1.2236 | Train Acc 0.3736
# Epoch 139: Train Loss 1.2236 | Train Acc 0.3736
# Epoch 140: Train Loss 1.2235 | Train Acc 0.3736
# Epoch 141: Train Loss 1.2235 | Train Acc 0.3736
# Epoch 142: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 143: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 144: Train Loss 1.2235 | Train Acc 0.3736
# Epoch 145: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 146: Train Loss 1.2235 | Train Acc 0.3736
# Epoch 147: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 148: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 149: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 150: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 151: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 152: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 153: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 154: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 155: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 156: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 157: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 158: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 159: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 160: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 161: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 162: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 163: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 164: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 165: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 166: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 167: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 168: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 169: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 170: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 171: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 172: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 173: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 174: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 175: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 176: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 177: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 178: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 179: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 180: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 181: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 182: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 183: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 184: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 185: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 186: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 187: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 188: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 189: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 190: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 191: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 192: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 193: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 194: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 195: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 196: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 197: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 198: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 199: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 200: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 201: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 202: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 203: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 204: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 205: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 206: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 207: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 208: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 209: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 210: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 211: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 212: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 213: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 214: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 215: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 216: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 217: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 218: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 219: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 220: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 221: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 222: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 223: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 224: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 225: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 226: Train Loss 1.2235 | Train Acc 0.3736
# Epoch 227: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 228: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 229: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 230: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 231: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 232: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 233: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 234: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 235: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 236: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 237: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 238: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 239: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 240: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 241: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 242: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 243: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 244: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 245: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 246: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 247: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 248: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 249: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 250: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 251: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 252: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 253: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 254: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 255: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 256: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 257: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 258: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 259: Train Loss 1.2232 | Train Acc 0.3736
# Epoch 260: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 261: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 262: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 263: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 264: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 265: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 266: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 267: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 268: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 269: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 270: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 271: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 272: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 273: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 274: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 275: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 276: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 277: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 278: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 279: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 280: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 281: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 282: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 283: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 284: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 285: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 286: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 287: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 288: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 289: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 290: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 291: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 292: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 293: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 294: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 295: Train Loss 1.2234 | Train Acc 0.3736
# Epoch 296: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 297: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 298: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 299: Train Loss 1.2233 | Train Acc 0.3736
# Epoch 300: Train Loss 1.2233 | Train Acc 0.3736
# Test Loss: 1.2219 | Test Acc: 0.3684
# 0.0 this is percent 0
# Predicted 0: 0.00%
# Predicted 1: 100.00%
#
# --- Fold 3 ---
# Epoch 1: Train Loss 1.7472 | Train Acc 0.6286
# Epoch 2: Train Loss 1.7376 | Train Acc 0.6286
# Epoch 3: Train Loss 1.7279 | Train Acc 0.6286
# Epoch 4: Train Loss 1.7185 | Train Acc 0.6286
# Epoch 5: Train Loss 1.7088 | Train Acc 0.6286
# Epoch 6: Train Loss 1.6992 | Train Acc 0.6286
# Epoch 7: Train Loss 1.6900 | Train Acc 0.6286
# Epoch 8: Train Loss 1.6805 | Train Acc 0.6286
# Epoch 9: Train Loss 1.6716 | Train Acc 0.6286
# Epoch 10: Train Loss 1.6626 | Train Acc 0.6286
# Epoch 11: Train Loss 1.6534 | Train Acc 0.6286
# Epoch 12: Train Loss 1.6445 | Train Acc 0.6286
# Epoch 13: Train Loss 1.6360 | Train Acc 0.6286
# Epoch 14: Train Loss 1.6279 | Train Acc 0.6286
# Epoch 15: Train Loss 1.6196 | Train Acc 0.6286
# Epoch 16: Train Loss 1.6117 | Train Acc 0.6286
# Epoch 17: Train Loss 1.6036 | Train Acc 0.6286
# Epoch 18: Train Loss 1.5956 | Train Acc 0.6286
# Epoch 19: Train Loss 1.5876 | Train Acc 0.6286
# Epoch 20: Train Loss 1.5799 | Train Acc 0.6286
# Epoch 21: Train Loss 1.5724 | Train Acc 0.6286
# Epoch 22: Train Loss 1.5651 | Train Acc 0.6286
# Epoch 23: Train Loss 1.5582 | Train Acc 0.6286
# Epoch 24: Train Loss 1.5513 | Train Acc 0.6286
# Epoch 25: Train Loss 1.5441 | Train Acc 0.6286
# Epoch 26: Train Loss 1.5374 | Train Acc 0.6286
# Epoch 27: Train Loss 1.5307 | Train Acc 0.6286
# Epoch 28: Train Loss 1.5242 | Train Acc 0.6286
# Epoch 29: Train Loss 1.5177 | Train Acc 0.6286
# Epoch 30: Train Loss 1.5113 | Train Acc 0.6286
# Epoch 31: Train Loss 1.5051 | Train Acc 0.6286
# Epoch 32: Train Loss 1.4986 | Train Acc 0.6286
# Epoch 33: Train Loss 1.4927 | Train Acc 0.6286
# Epoch 34: Train Loss 1.4867 | Train Acc 0.6286
# Epoch 35: Train Loss 1.4808 | Train Acc 0.6286
# Epoch 36: Train Loss 1.4749 | Train Acc 0.6286
# Epoch 37: Train Loss 1.4696 | Train Acc 0.6286
# Epoch 38: Train Loss 1.4639 | Train Acc 0.6286
# Epoch 39: Train Loss 1.4582 | Train Acc 0.6286
# Epoch 40: Train Loss 1.4527 | Train Acc 0.6286
# Epoch 41: Train Loss 1.4474 | Train Acc 0.6286
# Epoch 42: Train Loss 1.4418 | Train Acc 0.6286
# Epoch 43: Train Loss 1.4361 | Train Acc 0.6286
# Epoch 44: Train Loss 1.4310 | Train Acc 0.6286
# Epoch 45: Train Loss 1.4259 | Train Acc 0.6286
# Epoch 46: Train Loss 1.4210 | Train Acc 0.6286
# Epoch 47: Train Loss 1.4165 | Train Acc 0.6286
# Epoch 48: Train Loss 1.4116 | Train Acc 0.6286
# Epoch 49: Train Loss 1.4070 | Train Acc 0.6286
# Epoch 50: Train Loss 1.4026 | Train Acc 0.6286
# Epoch 51: Train Loss 1.3979 | Train Acc 0.6286
# Epoch 52: Train Loss 1.3939 | Train Acc 0.6286
# Epoch 53: Train Loss 1.3897 | Train Acc 0.6286
# Epoch 54: Train Loss 1.3856 | Train Acc 0.6286
# Epoch 55: Train Loss 1.3817 | Train Acc 0.6286
# Epoch 56: Train Loss 1.3779 | Train Acc 0.6286
# Epoch 57: Train Loss 1.3744 | Train Acc 0.6286
# Epoch 58: Train Loss 1.3708 | Train Acc 0.6286
# Epoch 59: Train Loss 1.3671 | Train Acc 0.6286
# Epoch 60: Train Loss 1.3636 | Train Acc 0.6286
# Epoch 61: Train Loss 1.3601 | Train Acc 0.6286
# Epoch 62: Train Loss 1.3567 | Train Acc 0.6286
# Epoch 63: Train Loss 1.3533 | Train Acc 0.6286
# Epoch 64: Train Loss 1.3497 | Train Acc 0.6286
# Epoch 65: Train Loss 1.3461 | Train Acc 0.4681
# Epoch 66: Train Loss 1.3426 | Train Acc 0.3714
# Epoch 67: Train Loss 1.3399 | Train Acc 0.3714
# Epoch 68: Train Loss 1.3368 | Train Acc 0.3714
# Epoch 69: Train Loss 1.3338 | Train Acc 0.3714
# Epoch 70: Train Loss 1.3308 | Train Acc 0.3714
# Epoch 71: Train Loss 1.3278 | Train Acc 0.3714
# Epoch 72: Train Loss 1.3248 | Train Acc 0.3714
# Epoch 73: Train Loss 1.3222 | Train Acc 0.3714
# Epoch 74: Train Loss 1.3195 | Train Acc 0.3714
# Epoch 75: Train Loss 1.3168 | Train Acc 0.3714
# Epoch 76: Train Loss 1.3140 | Train Acc 0.3714
# Epoch 77: Train Loss 1.3115 | Train Acc 0.3714
# Epoch 78: Train Loss 1.3091 | Train Acc 0.3714
# Epoch 79: Train Loss 1.3068 | Train Acc 0.3714
# Epoch 80: Train Loss 1.3047 | Train Acc 0.3714
# Epoch 81: Train Loss 1.3025 | Train Acc 0.3714
# Epoch 82: Train Loss 1.3002 | Train Acc 0.3714
# Epoch 83: Train Loss 1.2979 | Train Acc 0.3714
# Epoch 84: Train Loss 1.2957 | Train Acc 0.3714
# Epoch 85: Train Loss 1.2935 | Train Acc 0.3714
# Epoch 86: Train Loss 1.2914 | Train Acc 0.3714
# Epoch 87: Train Loss 1.2894 | Train Acc 0.3714
# Epoch 88: Train Loss 1.2874 | Train Acc 0.3714
# Epoch 89: Train Loss 1.2854 | Train Acc 0.3714
# Epoch 90: Train Loss 1.2836 | Train Acc 0.3714
# Epoch 91: Train Loss 1.2819 | Train Acc 0.3714
# Epoch 92: Train Loss 1.2801 | Train Acc 0.3714
# Epoch 93: Train Loss 1.2784 | Train Acc 0.3714
# Epoch 94: Train Loss 1.2768 | Train Acc 0.3714
# Epoch 95: Train Loss 1.2752 | Train Acc 0.3714
# Epoch 96: Train Loss 1.2737 | Train Acc 0.3714
# Epoch 97: Train Loss 1.2720 | Train Acc 0.3714
# Epoch 98: Train Loss 1.2707 | Train Acc 0.3714
# Epoch 99: Train Loss 1.2692 | Train Acc 0.3714
# Epoch 100: Train Loss 1.2679 | Train Acc 0.3714
# Epoch 101: Train Loss 1.2665 | Train Acc 0.3714
# Epoch 102: Train Loss 1.2653 | Train Acc 0.3714
# Epoch 103: Train Loss 1.2639 | Train Acc 0.3714
# Epoch 104: Train Loss 1.2624 | Train Acc 0.3714
# Epoch 105: Train Loss 1.2611 | Train Acc 0.3714
# Epoch 106: Train Loss 1.2598 | Train Acc 0.3714
# Epoch 107: Train Loss 1.2586 | Train Acc 0.3714
# Epoch 108: Train Loss 1.2573 | Train Acc 0.3714
# Epoch 109: Train Loss 1.2562 | Train Acc 0.3714
# Epoch 110: Train Loss 1.2550 | Train Acc 0.3714
# Epoch 111: Train Loss 1.2540 | Train Acc 0.3714
# Epoch 112: Train Loss 1.2530 | Train Acc 0.3714
# Epoch 113: Train Loss 1.2520 | Train Acc 0.3714
# Epoch 114: Train Loss 1.2511 | Train Acc 0.3714
# Epoch 115: Train Loss 1.2500 | Train Acc 0.3714
# Epoch 116: Train Loss 1.2492 | Train Acc 0.3714
# Epoch 117: Train Loss 1.2483 | Train Acc 0.3714
# Epoch 118: Train Loss 1.2475 | Train Acc 0.3714
# Epoch 119: Train Loss 1.2466 | Train Acc 0.3714
# Epoch 120: Train Loss 1.2458 | Train Acc 0.3714
# Epoch 121: Train Loss 1.2451 | Train Acc 0.3714
# Epoch 122: Train Loss 1.2442 | Train Acc 0.3714
# Epoch 123: Train Loss 1.2435 | Train Acc 0.3714
# Epoch 124: Train Loss 1.2427 | Train Acc 0.3714
# Epoch 125: Train Loss 1.2420 | Train Acc 0.3714
# Epoch 126: Train Loss 1.2413 | Train Acc 0.3714
# Epoch 127: Train Loss 1.2406 | Train Acc 0.3714
# Epoch 128: Train Loss 1.2399 | Train Acc 0.3714
# Epoch 129: Train Loss 1.2392 | Train Acc 0.3714
# Epoch 130: Train Loss 1.2386 | Train Acc 0.3714
# Epoch 131: Train Loss 1.2381 | Train Acc 0.3714
# Epoch 132: Train Loss 1.2376 | Train Acc 0.3714
# Epoch 133: Train Loss 1.2370 | Train Acc 0.3714
# Epoch 134: Train Loss 1.2366 | Train Acc 0.3714
# Epoch 135: Train Loss 1.2360 | Train Acc 0.3714
# Epoch 136: Train Loss 1.2354 | Train Acc 0.3714
# Epoch 137: Train Loss 1.2350 | Train Acc 0.3714
# Epoch 138: Train Loss 1.2346 | Train Acc 0.3714
# Epoch 139: Train Loss 1.2342 | Train Acc 0.3714
# Epoch 140: Train Loss 1.2338 | Train Acc 0.3714
# Epoch 141: Train Loss 1.2333 | Train Acc 0.3714
# Epoch 142: Train Loss 1.2330 | Train Acc 0.3714
# Epoch 143: Train Loss 1.2326 | Train Acc 0.3714
# Epoch 144: Train Loss 1.2323 | Train Acc 0.3714
# Epoch 145: Train Loss 1.2320 | Train Acc 0.3714
# Epoch 146: Train Loss 1.2316 | Train Acc 0.3714
# Epoch 147: Train Loss 1.2313 | Train Acc 0.3714
# Epoch 148: Train Loss 1.2310 | Train Acc 0.3714
# Epoch 149: Train Loss 1.2307 | Train Acc 0.3714
# Epoch 150: Train Loss 1.2304 | Train Acc 0.3714
# Epoch 151: Train Loss 1.2302 | Train Acc 0.3714
# Epoch 152: Train Loss 1.2299 | Train Acc 0.3714
# Epoch 153: Train Loss 1.2296 | Train Acc 0.3714
# Epoch 154: Train Loss 1.2293 | Train Acc 0.3714
# Epoch 155: Train Loss 1.2292 | Train Acc 0.3714
# Epoch 156: Train Loss 1.2289 | Train Acc 0.3714
# Epoch 157: Train Loss 1.2287 | Train Acc 0.3714
# Epoch 158: Train Loss 1.2285 | Train Acc 0.3714
# Epoch 159: Train Loss 1.2283 | Train Acc 0.3714
# Epoch 160: Train Loss 1.2281 | Train Acc 0.3714
# Epoch 161: Train Loss 1.2279 | Train Acc 0.3714
# Epoch 162: Train Loss 1.2276 | Train Acc 0.3714
# Epoch 163: Train Loss 1.2273 | Train Acc 0.3714
# Epoch 164: Train Loss 1.2272 | Train Acc 0.3714
# Epoch 165: Train Loss 1.2270 | Train Acc 0.3714
# Epoch 166: Train Loss 1.2268 | Train Acc 0.3714
# Epoch 167: Train Loss 1.2266 | Train Acc 0.3714
# Epoch 168: Train Loss 1.2265 | Train Acc 0.3714
# Epoch 169: Train Loss 1.2263 | Train Acc 0.3714
# Epoch 170: Train Loss 1.2262 | Train Acc 0.3714
# Epoch 171: Train Loss 1.2261 | Train Acc 0.3714
# Epoch 172: Train Loss 1.2259 | Train Acc 0.3714
# Epoch 173: Train Loss 1.2258 | Train Acc 0.3714
# Epoch 174: Train Loss 1.2257 | Train Acc 0.3714
# Epoch 175: Train Loss 1.2255 | Train Acc 0.3714
# Epoch 176: Train Loss 1.2254 | Train Acc 0.3714
# Epoch 177: Train Loss 1.2253 | Train Acc 0.3714
# Epoch 178: Train Loss 1.2251 | Train Acc 0.3714
# Epoch 179: Train Loss 1.2251 | Train Acc 0.3714
# Epoch 180: Train Loss 1.2250 | Train Acc 0.3714
# Epoch 181: Train Loss 1.2249 | Train Acc 0.3714
# Epoch 182: Train Loss 1.2248 | Train Acc 0.3714
# Epoch 183: Train Loss 1.2247 | Train Acc 0.3714
# Epoch 184: Train Loss 1.2246 | Train Acc 0.3714
# Epoch 185: Train Loss 1.2246 | Train Acc 0.3714
# Epoch 186: Train Loss 1.2244 | Train Acc 0.3714
# Epoch 187: Train Loss 1.2243 | Train Acc 0.3714
# Epoch 188: Train Loss 1.2243 | Train Acc 0.3714
# Epoch 189: Train Loss 1.2243 | Train Acc 0.3714
# Epoch 190: Train Loss 1.2241 | Train Acc 0.3714
# Epoch 191: Train Loss 1.2241 | Train Acc 0.3714
# Epoch 192: Train Loss 1.2240 | Train Acc 0.3714
# Epoch 193: Train Loss 1.2240 | Train Acc 0.3714
# Epoch 194: Train Loss 1.2239 | Train Acc 0.3714
# Epoch 195: Train Loss 1.2239 | Train Acc 0.3714
# Epoch 196: Train Loss 1.2238 | Train Acc 0.3714
# Epoch 197: Train Loss 1.2238 | Train Acc 0.3714
# Epoch 198: Train Loss 1.2237 | Train Acc 0.3714
# Epoch 199: Train Loss 1.2237 | Train Acc 0.3714
# Epoch 200: Train Loss 1.2236 | Train Acc 0.3714
# Epoch 201: Train Loss 1.2236 | Train Acc 0.3714
# Epoch 202: Train Loss 1.2236 | Train Acc 0.3714
# Epoch 203: Train Loss 1.2236 | Train Acc 0.3714
# Epoch 204: Train Loss 1.2235 | Train Acc 0.3714
# Epoch 205: Train Loss 1.2234 | Train Acc 0.3714
# Epoch 206: Train Loss 1.2234 | Train Acc 0.3714
# Epoch 207: Train Loss 1.2234 | Train Acc 0.3714
# Epoch 208: Train Loss 1.2233 | Train Acc 0.3714
# Epoch 209: Train Loss 1.2233 | Train Acc 0.3714
# Epoch 210: Train Loss 1.2233 | Train Acc 0.3714
# Epoch 211: Train Loss 1.2232 | Train Acc 0.3714
# Epoch 212: Train Loss 1.2232 | Train Acc 0.3714
# Epoch 213: Train Loss 1.2232 | Train Acc 0.3714
# Epoch 214: Train Loss 1.2232 | Train Acc 0.3714
# Epoch 215: Train Loss 1.2232 | Train Acc 0.3714
# Epoch 216: Train Loss 1.2232 | Train Acc 0.3714
# Epoch 217: Train Loss 1.2231 | Train Acc 0.3714
# Epoch 218: Train Loss 1.2231 | Train Acc 0.3714
# Epoch 219: Train Loss 1.2231 | Train Acc 0.3714
# Epoch 220: Train Loss 1.2230 | Train Acc 0.3714
# Epoch 221: Train Loss 1.2230 | Train Acc 0.3714
# Epoch 222: Train Loss 1.2230 | Train Acc 0.3714
# Epoch 223: Train Loss 1.2230 | Train Acc 0.3714
# Epoch 224: Train Loss 1.2230 | Train Acc 0.3714
# Epoch 225: Train Loss 1.2230 | Train Acc 0.3714
# Epoch 226: Train Loss 1.2230 | Train Acc 0.3714
# Epoch 227: Train Loss 1.2230 | Train Acc 0.3714
# Epoch 228: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 229: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 230: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 231: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 232: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 233: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 234: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 235: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 236: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 237: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 238: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 239: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 240: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 241: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 242: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 243: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 244: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 245: Train Loss 1.2230 | Train Acc 0.3714
# Epoch 246: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 247: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 248: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 249: Train Loss 1.2229 | Train Acc 0.3714
# Epoch 250: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 251: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 252: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 253: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 254: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 255: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 256: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 257: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 258: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 259: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 260: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 261: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 262: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 263: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 264: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 265: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 266: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 267: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 268: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 269: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 270: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 271: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 272: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 273: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 274: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 275: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 276: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 277: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 278: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 279: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 280: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 281: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 282: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 283: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 284: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 285: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 286: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 287: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 288: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 289: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 290: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 291: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 292: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 293: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 294: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 295: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 296: Train Loss 1.2227 | Train Acc 0.3714
# Epoch 297: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 298: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 299: Train Loss 1.2228 | Train Acc 0.3714
# Epoch 300: Train Loss 1.2227 | Train Acc 0.3714
# Test Loss: 1.2242 | Test Acc: 0.3772
# 0.0 this is percent 0
# Predicted 0: 0.00%
# Predicted 1: 100.00%
#
# --- Fold 4 ---
# Epoch 1: Train Loss 1.3699 | Train Acc 0.6286
# Epoch 2: Train Loss 1.3590 | Train Acc 0.6286
# Epoch 3: Train Loss 1.3502 | Train Acc 0.6286
# Epoch 4: Train Loss 1.3455 | Train Acc 0.7516
# Epoch 5: Train Loss 1.3408 | Train Acc 0.6374
# Epoch 6: Train Loss 1.3356 | Train Acc 0.3714
# Epoch 7: Train Loss 1.3303 | Train Acc 0.3714
# Epoch 8: Train Loss 1.3249 | Train Acc 0.3714
# Epoch 9: Train Loss 1.3198 | Train Acc 0.3714
# Epoch 10: Train Loss 1.3147 | Train Acc 0.3714
# Epoch 11: Train Loss 1.3096 | Train Acc 0.3714
# Epoch 12: Train Loss 1.3040 | Train Acc 0.3714
# Epoch 13: Train Loss 1.2982 | Train Acc 0.3714
# Epoch 14: Train Loss 1.2925 | Train Acc 0.3714
# Epoch 15: Train Loss 1.2864 | Train Acc 0.3714
# Epoch 16: Train Loss 1.2802 | Train Acc 0.3714
# Epoch 17: Train Loss 1.2731 | Train Acc 0.3714
# Epoch 18: Train Loss 1.2661 | Train Acc 0.3714
# Epoch 19: Train Loss 1.2581 | Train Acc 0.3714
# Epoch 20: Train Loss 1.2498 | Train Acc 0.3714
# Epoch 21: Train Loss 1.2417 | Train Acc 0.3714
# Epoch 22: Train Loss 1.2327 | Train Acc 0.3714
# Epoch 23: Train Loss 1.2235 | Train Acc 0.3714
# Epoch 24: Train Loss 1.2148 | Train Acc 0.7890
# Epoch 25: Train Loss 1.2039 | Train Acc 0.9099
# Epoch 26: Train Loss 1.1939 | Train Acc 0.8901
# Epoch 27: Train Loss 1.1846 | Train Acc 0.9121
# Epoch 28: Train Loss 1.1739 | Train Acc 0.9187
# Epoch 29: Train Loss 1.1609 | Train Acc 0.9341
# Epoch 30: Train Loss 1.1506 | Train Acc 0.9495
# Epoch 31: Train Loss 1.1388 | Train Acc 0.9341
# Epoch 32: Train Loss 1.1270 | Train Acc 0.9538
# Epoch 33: Train Loss 1.1160 | Train Acc 0.9560
# Epoch 34: Train Loss 1.1042 | Train Acc 0.9538
# Epoch 35: Train Loss 1.0938 | Train Acc 0.9538
# Epoch 36: Train Loss 1.0789 | Train Acc 0.9736
# Epoch 37: Train Loss 1.0658 | Train Acc 0.9560
# Epoch 38: Train Loss 1.0538 | Train Acc 0.9736
# Epoch 39: Train Loss 1.0420 | Train Acc 0.9780
# Epoch 40: Train Loss 1.0310 | Train Acc 0.9846
# Epoch 41: Train Loss 1.0158 | Train Acc 0.9736
# Epoch 42: Train Loss 1.0051 | Train Acc 0.9714
# Epoch 43: Train Loss 1.0037 | Train Acc 0.9429
# Epoch 44: Train Loss 0.9877 | Train Acc 0.9736
# Epoch 45: Train Loss 0.9702 | Train Acc 0.9758
# Epoch 46: Train Loss 0.9536 | Train Acc 0.9780
# Epoch 47: Train Loss 0.9445 | Train Acc 0.9626
# Epoch 48: Train Loss 0.9344 | Train Acc 0.9802
# Epoch 49: Train Loss 0.9169 | Train Acc 0.9780
# Epoch 50: Train Loss 0.9045 | Train Acc 0.9824
# Epoch 51: Train Loss 0.8941 | Train Acc 0.9846
# Epoch 52: Train Loss 0.8814 | Train Acc 0.9780
# Epoch 53: Train Loss 0.8688 | Train Acc 0.9890
# Epoch 54: Train Loss 0.8576 | Train Acc 0.9780
# Epoch 55: Train Loss 0.8517 | Train Acc 0.9714
# Epoch 56: Train Loss 0.8360 | Train Acc 0.9890
# Epoch 57: Train Loss 0.8226 | Train Acc 0.9846
# Epoch 58: Train Loss 0.8106 | Train Acc 0.9868
# Epoch 59: Train Loss 0.8014 | Train Acc 0.9824
# Epoch 60: Train Loss 0.7882 | Train Acc 0.9868
# Epoch 61: Train Loss 0.7893 | Train Acc 0.9758
# Epoch 62: Train Loss 0.7823 | Train Acc 0.9626
# Epoch 63: Train Loss 0.7623 | Train Acc 0.9824
# Epoch 64: Train Loss 0.7493 | Train Acc 0.9758
# Epoch 65: Train Loss 0.7412 | Train Acc 0.9912
# Epoch 66: Train Loss 0.7295 | Train Acc 0.9824
# Epoch 67: Train Loss 0.7220 | Train Acc 0.9714
# Epoch 68: Train Loss 0.7176 | Train Acc 0.9824
# Epoch 69: Train Loss 0.7056 | Train Acc 0.9824
# Epoch 70: Train Loss 0.6946 | Train Acc 0.9824
# Epoch 71: Train Loss 0.7115 | Train Acc 0.9846
# Epoch 72: Train Loss 0.6770 | Train Acc 0.9824
# Epoch 73: Train Loss 0.6691 | Train Acc 0.9846
# Epoch 74: Train Loss 0.6632 | Train Acc 0.9868
# Epoch 75: Train Loss 0.6561 | Train Acc 0.9868
# Epoch 76: Train Loss 0.6496 | Train Acc 0.9824
# Epoch 77: Train Loss 0.6360 | Train Acc 0.9824
# Epoch 78: Train Loss 0.6462 | Train Acc 0.9758
# Epoch 79: Train Loss 0.6431 | Train Acc 0.9582
# Epoch 80: Train Loss 0.6112 | Train Acc 0.9890
# Epoch 81: Train Loss 0.6075 | Train Acc 0.9802
# Epoch 82: Train Loss 0.5951 | Train Acc 0.9912
# Epoch 83: Train Loss 0.5892 | Train Acc 0.9868
# Epoch 84: Train Loss 0.5811 | Train Acc 0.9802
# Epoch 85: Train Loss 0.5751 | Train Acc 0.9890
# Epoch 86: Train Loss 0.5667 | Train Acc 0.9824
# Epoch 87: Train Loss 0.5621 | Train Acc 0.9890
# Epoch 88: Train Loss 0.5600 | Train Acc 0.9824
# Epoch 89: Train Loss 0.5887 | Train Acc 0.9473
# Epoch 90: Train Loss 0.5436 | Train Acc 0.9868
# Epoch 91: Train Loss 0.5348 | Train Acc 0.9868
# Epoch 92: Train Loss 0.5370 | Train Acc 0.9780
# Epoch 93: Train Loss 0.5237 | Train Acc 0.9912
# Epoch 94: Train Loss 0.5207 | Train Acc 0.9846
# Epoch 95: Train Loss 0.5100 | Train Acc 0.9868
# Epoch 96: Train Loss 0.5038 | Train Acc 0.9846
# Epoch 97: Train Loss 0.5063 | Train Acc 0.9846
# Epoch 98: Train Loss 0.5084 | Train Acc 0.9780
# Epoch 99: Train Loss 0.4998 | Train Acc 0.9846
# Epoch 100: Train Loss 0.4822 | Train Acc 0.9890
# Epoch 101: Train Loss 0.4862 | Train Acc 0.9824
# ...
# Epoch 271: Train Loss 0.1407 | Train Acc 0.9934
# Epoch 272: Train Loss 0.1383 | Train Acc 0.9956
# Epoch 273: Train Loss 0.1376 | Train Acc 0.9934
# Epoch 274: Train Loss 0.1402 | Train Acc 0.9934
# Epoch 275: Train Loss 0.1370 | Train Acc 0.9912
# Epoch 276: Train Loss 0.1411 | Train Acc 0.9956
# Epoch 277: Train Loss 0.1385 | Train Acc 0.9934
# Epoch 278: Train Loss 0.1365 | Train Acc 0.9934
# Epoch 279: Train Loss 0.1394 | Train Acc 0.9934
# Epoch 280: Train Loss 0.1540 | Train Acc 0.9846
# Epoch 281: Train Loss 0.1335 | Train Acc 0.9934
# Epoch 282: Train Loss 0.1327 | Train Acc 0.9956
# Epoch 283: Train Loss 0.1308 | Train Acc 0.9956
# Epoch 284: Train Loss 0.1313 | Train Acc 0.9956
# Epoch 285: Train Loss 0.1332 | Train Acc 0.9890
# Epoch 286: Train Loss 0.1295 | Train Acc 0.9956
# Epoch 287: Train Loss 0.1327 | Train Acc 0.9934
# Epoch 288: Train Loss 0.1301 | Train Acc 0.9890
# Epoch 289: Train Loss 0.1316 | Train Acc 0.9912
# Epoch 290: Train Loss 0.1306 | Train Acc 0.9956
# Epoch 291: Train Loss 0.1294 | Train Acc 0.9912
# Epoch 292: Train Loss 0.1256 | Train Acc 0.9956
# Epoch 293: Train Loss 0.1262 | Train Acc 0.9956
# Epoch 294: Train Loss 0.1260 | Train Acc 0.9934
# Epoch 295: Train Loss 0.1248 | Train Acc 0.9956
# Epoch 296: Train Loss 0.1234 | Train Acc 0.9956
# Epoch 297: Train Loss 0.1227 | Train Acc 0.9956
# Epoch 298: Train Loss 0.1216 | Train Acc 0.9956
# Epoch 299: Train Loss 0.1220 | Train Acc 0.9956
# Epoch 300: Train Loss 0.1250 | Train Acc 0.9934
# Test Loss: 0.3190 | Test Acc: 0.9474
# 58.77192982456141 this is percent 0
# Predicted 0: 58.77%
# Predicted 1: 41.23%
#
# --- Fold 5 ---
# Epoch 1: Train Loss 1.2231 | Train Acc 0.3728
# Epoch 2: Train Loss 1.2186 | Train Acc 0.3728
# Epoch 3: Train Loss 1.2113 | Train Acc 0.3728
# Epoch 4: Train Loss 1.1988 | Train Acc 0.3728
# Epoch 5: Train Loss 1.1789 | Train Acc 0.3728
# Epoch 6: Train Loss 1.1440 | Train Acc 0.3728
# Epoch 7: Train Loss 1.0857 | Train Acc 0.3728
# Epoch 8: Train Loss 1.0107 | Train Acc 0.3728
# Epoch 9: Train Loss 0.9395 | Train Acc 0.3728
# Epoch 10: Train Loss 0.8795 | Train Acc 0.3728
# Epoch 11: Train Loss 0.8351 | Train Acc 0.3728
# Epoch 12: Train Loss 0.8037 | Train Acc 0.3728
# Epoch 13: Train Loss 0.7776 | Train Acc 0.3728
# Epoch 14: Train Loss 0.7618 | Train Acc 0.3728
# Epoch 15: Train Loss 0.7396 | Train Acc 0.3728
# Epoch 16: Train Loss 0.7276 | Train Acc 0.3728
# Epoch 17: Train Loss 0.7126 | Train Acc 0.3728
# Epoch 18: Train Loss 0.6981 | Train Acc 0.3728
# Epoch 19: Train Loss 0.6888 | Train Acc 0.3728
# Epoch 20: Train Loss 0.6740 | Train Acc 0.3728
# Epoch 21: Train Loss 0.6650 | Train Acc 0.3728
# Epoch 22: Train Loss 0.6562 | Train Acc 0.3728
# Epoch 23: Train Loss 0.6428 | Train Acc 0.3728
# Epoch 24: Train Loss 0.6453 | Train Acc 0.3728
# Epoch 25: Train Loss 0.6368 | Train Acc 0.3728
# Epoch 26: Train Loss 0.6159 | Train Acc 0.3728
# Epoch 27: Train Loss 0.6034 | Train Acc 0.3728
# Epoch 28: Train Loss 0.5970 | Train Acc 0.3728
# Epoch 29: Train Loss 0.5883 | Train Acc 0.3728
# Epoch 30: Train Loss 0.5824 | Train Acc 0.3728
# Epoch 31: Train Loss 0.5816 | Train Acc 0.3728
# Epoch 32: Train Loss 0.5657 | Train Acc 0.3728
# Epoch 33: Train Loss 0.5571 | Train Acc 0.3728
# Epoch 34: Train Loss 0.5557 | Train Acc 0.3728
# Epoch 35: Train Loss 0.5470 | Train Acc 0.3728
# Epoch 36: Train Loss 0.5415 | Train Acc 0.3728
# Epoch 37: Train Loss 0.5359 | Train Acc 0.3728
# Epoch 38: Train Loss 0.5276 | Train Acc 0.3728
# Epoch 39: Train Loss 0.5224 | Train Acc 0.3728
# Epoch 40: Train Loss 0.5179 | Train Acc 0.3728
# Epoch 41: Train Loss 0.5175 | Train Acc 0.3728
# Epoch 42: Train Loss 0.5129 | Train Acc 0.3728
# Epoch 43: Train Loss 0.5081 | Train Acc 0.3728
# Epoch 44: Train Loss 0.5015 | Train Acc 0.3728
# Epoch 45: Train Loss 0.5004 | Train Acc 0.3728
# Epoch 46: Train Loss 0.4894 | Train Acc 0.3728
# Epoch 47: Train Loss 0.4803 | Train Acc 0.3728
# Epoch 48: Train Loss 0.4773 | Train Acc 0.5351
# Epoch 49: Train Loss 0.4728 | Train Acc 0.9693
# Epoch 50: Train Loss 0.4678 | Train Acc 0.9583
# Epoch 51: Train Loss 0.4629 | Train Acc 0.9759
# Epoch 52: Train Loss 0.4586 | Train Acc 0.9605
# Epoch 53: Train Loss 0.4635 | Train Acc 0.9605
# Epoch 54: Train Loss 0.4558 | Train Acc 0.9781
# Epoch 55: Train Loss 0.4545 | Train Acc 0.9452
# Epoch 56: Train Loss 0.4494 | Train Acc 0.9846
# Epoch 57: Train Loss 0.4397 | Train Acc 0.9671
# Epoch 58: Train Loss 0.4331 | Train Acc 0.9737
# Epoch 59: Train Loss 0.4307 | Train Acc 0.9671
# Epoch 60: Train Loss 0.4333 | Train Acc 0.9759
# Epoch 61: Train Loss 0.4252 | Train Acc 0.9715
# Epoch 62: Train Loss 0.4201 | Train Acc 0.9693
# Epoch 63: Train Loss 0.4233 | Train Acc 0.9803
# Epoch 64: Train Loss 0.4111 | Train Acc 0.9715
# Epoch 65: Train Loss 0.4118 | Train Acc 0.9803
# Epoch 66: Train Loss 0.4053 | Train Acc 0.9737
# Epoch 67: Train Loss 0.4008 | Train Acc 0.9759
# Epoch 68: Train Loss 0.4019 | Train Acc 0.9693
# Epoch 69: Train Loss 0.3980 | Train Acc 0.9803
# Epoch 70: Train Loss 0.3886 | Train Acc 0.9781
# Epoch 71: Train Loss 0.3906 | Train Acc 0.9803
# Epoch 72: Train Loss 0.3926 | Train Acc 0.9759
# Epoch 73: Train Loss 0.3922 | Train Acc 0.9605
# Epoch 74: Train Loss 0.3820 | Train Acc 0.9781
# Epoch 75: Train Loss 0.3705 | Train Acc 0.9781
# Epoch 76: Train Loss 0.3707 | Train Acc 0.9803
# Epoch 77: Train Loss 0.3703 | Train Acc 0.9781
# Epoch 78: Train Loss 0.3649 | Train Acc 0.9715
# Epoch 79: Train Loss 0.3598 | Train Acc 0.9737
# Epoch 80: Train Loss 0.3632 | Train Acc 0.9781
# Epoch 81: Train Loss 0.3648 | Train Acc 0.9825
# Epoch 82: Train Loss 0.3576 | Train Acc 0.9781
# Epoch 83: Train Loss 0.3553 | Train Acc 0.9627
# Epoch 84: Train Loss 0.3476 | Train Acc 0.9803
# Epoch 85: Train Loss 0.3434 | Train Acc 0.9715
# Epoch 86: Train Loss 0.3451 | Train Acc 0.9868
# Epoch 87: Train Loss 0.3351 | Train Acc 0.9781
# Epoch 88: Train Loss 0.3310 | Train Acc 0.9846
# Epoch 89: Train Loss 0.3355 | Train Acc 0.9803
# Epoch 90: Train Loss 0.3338 | Train Acc 0.9781
# Epoch 91: Train Loss 0.3249 | Train Acc 0.9846
# Epoch 92: Train Loss 0.3260 | Train Acc 0.9803
# Epoch 93: Train Loss 0.3192 | Train Acc 0.9846
# Epoch 94: Train Loss 0.3153 | Train Acc 0.9803
# Epoch 95: Train Loss 0.3166 | Train Acc 0.9846
# Epoch 96: Train Loss 0.3095 | Train Acc 0.9846
# Epoch 97: Train Loss 0.3106 | Train Acc 0.9846
# Epoch 98: Train Loss 0.3047 | Train Acc 0.9890
# Epoch 99: Train Loss 0.3029 | Train Acc 0.9825
# Epoch 100: Train Loss 0.3005 | Train Acc 0.9825
# Epoch 101: Train Loss 0.3016 | Train Acc 0.9868
# Epoch 102: Train Loss 0.2948 | Train Acc 0.9912
# Epoch 103: Train Loss 0.2923 | Train Acc 0.9868
# Epoch 104: Train Loss 0.2924 | Train Acc 0.9912
# Epoch 105: Train Loss 0.2959 | Train Acc 0.9890
# Epoch 106: Train Loss 0.2857 | Train Acc 0.9825
# Epoch 107: Train Loss 0.2870 | Train Acc 0.9846
# Epoch 108: Train Loss 0.2827 | Train Acc 0.9846
# Epoch 109: Train Loss 0.2777 | Train Acc 0.9846
# Epoch 110: Train Loss 0.2803 | Train Acc 0.9868
# Epoch 111: Train Loss 0.2798 | Train Acc 0.9846
# Epoch 112: Train Loss 0.2765 | Train Acc 0.9803
# Epoch 113: Train Loss 0.2753 | Train Acc 0.9890
# Epoch 114: Train Loss 0.2767 | Train Acc 0.9825
# Epoch 115: Train Loss 0.2705 | Train Acc 0.9868
# Epoch 116: Train Loss 0.2716 | Train Acc 0.9781
# Epoch 117: Train Loss 0.2609 | Train Acc 0.9890
# Epoch 118: Train Loss 0.2584 | Train Acc 0.9912
# Epoch 119: Train Loss 0.2584 | Train Acc 0.9912
# Epoch 120: Train Loss 0.2592 | Train Acc 0.9825
# Epoch 121: Train Loss 0.2502 | Train Acc 0.9890
# Epoch 122: Train Loss 0.2499 | Train Acc 0.9912
# Epoch 123: Train Loss 0.2527 | Train Acc 0.9912
# Epoch 124: Train Loss 0.2453 | Train Acc 0.9912
# Epoch 125: Train Loss 0.2458 | Train Acc 0.9890
# Epoch 126: Train Loss 0.2442 | Train Acc 0.9868
# Epoch 127: Train Loss 0.2413 | Train Acc 0.9912
# Epoch 128: Train Loss 0.2447 | Train Acc 0.9912
# Epoch 129: Train Loss 0.2371 | Train Acc 0.9890
# Epoch 130: Train Loss 0.2377 | Train Acc 0.9934
# Epoch 131: Train Loss 0.2424 | Train Acc 0.9846
# Epoch 132: Train Loss 0.2354 | Train Acc 0.9912
# Epoch 133: Train Loss 0.2353 | Train Acc 0.9890
# Epoch 134: Train Loss 0.2283 | Train Acc 0.9890
# Epoch 135: Train Loss 0.2274 | Train Acc 0.9934
# Epoch 136: Train Loss 0.2253 | Train Acc 0.9934
# Epoch 137: Train Loss 0.2259 | Train Acc 0.9890
# Epoch 138: Train Loss 0.2503 | Train Acc 0.9868
# Epoch 139: Train Loss 0.2253 | Train Acc 0.9912
# Epoch 140: Train Loss 0.2228 | Train Acc 0.9846
# Epoch 141: Train Loss 0.2269 | Train Acc 0.9890
# Epoch 142: Train Loss 0.2155 | Train Acc 0.9934
# Epoch 143: Train Loss 0.2149 | Train Acc 0.9912
# Epoch 144: Train Loss 0.2194 | Train Acc 0.9825
# Epoch 145: Train Loss 0.2228 | Train Acc 0.9912
# Epoch 146: Train Loss 0.2086 | Train Acc 0.9912
# Epoch 147: Train Loss 0.2116 | Train Acc 0.9912
# Epoch 148: Train Loss 0.2111 | Train Acc 0.9868
# Epoch 149: Train Loss 0.2047 | Train Acc 0.9912
# Epoch 150: Train Loss 0.2051 | Train Acc 0.9912
# Epoch 151: Train Loss 0.2015 | Train Acc 0.9934
# Epoch 152: Train Loss 0.1994 | Train Acc 0.9912
# Epoch 153: Train Loss 0.1992 | Train Acc 0.9934
# Epoch 154: Train Loss 0.1994 | Train Acc 0.9912
# Epoch 155: Train Loss 0.1989 | Train Acc 0.9912
# Epoch 156: Train Loss 0.2023 | Train Acc 0.9890
# Epoch 157: Train Loss 0.2000 | Train Acc 0.9912
# Epoch 158: Train Loss 0.1917 | Train Acc 0.9912
# Epoch 159: Train Loss 0.1914 | Train Acc 0.9912
# Epoch 160: Train Loss 0.1951 | Train Acc 0.9934
# Epoch 161: Train Loss 0.1946 | Train Acc 0.9912
# Epoch 162: Train Loss 0.1873 | Train Acc 0.9934
# Epoch 163: Train Loss 0.1869 | Train Acc 0.9934
# Epoch 164: Train Loss 0.1923 | Train Acc 0.9825
# Epoch 165: Train Loss 0.2214 | Train Acc 0.9781
# Epoch 166: Train Loss 0.1933 | Train Acc 0.9934
# Epoch 167: Train Loss 0.2016 | Train Acc 0.9846
# Epoch 168: Train Loss 0.1809 | Train Acc 0.9934
# Epoch 169: Train Loss 0.1792 | Train Acc 0.9934
# Epoch 170: Train Loss 0.1772 | Train Acc 0.9934
# Epoch 171: Train Loss 0.1822 | Train Acc 0.9890
# Epoch 172: Train Loss 0.1793 | Train Acc 0.9912
# Epoch 173: Train Loss 0.1748 | Train Acc 0.9912
# Epoch 174: Train Loss 0.1795 | Train Acc 0.9934
# Epoch 175: Train Loss 0.1727 | Train Acc 0.9934
# Epoch 176: Train Loss 0.1841 | Train Acc 0.9825
# Epoch 177: Train Loss 0.1769 | Train Acc 0.9934
# Epoch 178: Train Loss 0.1700 | Train Acc 0.9934
# Epoch 179: Train Loss 0.1690 | Train Acc 0.9912
# Epoch 180: Train Loss 0.1677 | Train Acc 0.9956
# Epoch 181: Train Loss 0.1700 | Train Acc 0.9912
# Epoch 182: Train Loss 0.1647 | Train Acc 0.9934
# Epoch 183: Train Loss 0.1647 | Train Acc 0.9934
# Epoch 184: Train Loss 0.1639 | Train Acc 0.9912
# Epoch 185: Train Loss 0.1617 | Train Acc 0.9934
# Epoch 186: Train Loss 0.1625 | Train Acc 0.9912
# Epoch 187: Train Loss 0.1610 | Train Acc 0.9934
# Epoch 188: Train Loss 0.1592 | Train Acc 0.9934
# Epoch 189: Train Loss 0.1576 | Train Acc 0.9934
# Epoch 190: Train Loss 0.1568 | Train Acc 0.9934
# Epoch 191: Train Loss 0.1585 | Train Acc 0.9934
# Epoch 192: Train Loss 0.1561 | Train Acc 0.9934
# Epoch 193: Train Loss 0.1543 | Train Acc 0.9934
# Epoch 194: Train Loss 0.1599 | Train Acc 0.9912
# Epoch 195: Train Loss 0.1517 | Train Acc 0.9934
# Epoch 196: Train Loss 0.1515 | Train Acc 0.9934
# Epoch 197: Train Loss 0.1508 | Train Acc 0.9934
# Epoch 198: Train Loss 0.1495 | Train Acc 0.9934
# Epoch 199: Train Loss 0.1518 | Train Acc 0.9956
# Epoch 200: Train Loss 0.1695 | Train Acc 0.9868
# Epoch 201: Train Loss 0.2109 | Train Acc 0.9693
# Epoch 202: Train Loss 0.1549 | Train Acc 0.9868
# Epoch 203: Train Loss 0.1499 | Train Acc 0.9912
# Epoch 204: Train Loss 0.1484 | Train Acc 0.9912
# Epoch 205: Train Loss 0.1478 | Train Acc 0.9934
# Epoch 206: Train Loss 0.1458 | Train Acc 0.9912
# Epoch 207: Train Loss 0.1469 | Train Acc 0.9934
# Epoch 208: Train Loss 0.1431 | Train Acc 0.9934
# Epoch 209: Train Loss 0.1446 | Train Acc 0.9934
# Epoch 210: Train Loss 0.1457 | Train Acc 0.9934
# Epoch 211: Train Loss 0.1398 | Train Acc 0.9934
# Epoch 212: Train Loss 0.1401 | Train Acc 0.9956
# Epoch 213: Train Loss 0.1408 | Train Acc 0.9934
# Epoch 214: Train Loss 0.1377 | Train Acc 0.9956
# Epoch 215: Train Loss 0.1388 | Train Acc 0.9934
# Epoch 216: Train Loss 0.1400 | Train Acc 0.9956
# Epoch 217: Train Loss 0.1497 | Train Acc 0.9846
# Epoch 218: Train Loss 0.1372 | Train Acc 0.9934
# Epoch 219: Train Loss 0.1345 | Train Acc 0.9956
# Epoch 220: Train Loss 0.1369 | Train Acc 0.9912
# Epoch 221: Train Loss 0.1377 | Train Acc 0.9956
# Epoch 222: Train Loss 0.1484 | Train Acc 0.9825
# Epoch 223: Train Loss 0.1449 | Train Acc 0.9934
# Epoch 224: Train Loss 0.1446 | Train Acc 0.9912
# Epoch 225: Train Loss 0.1327 | Train Acc 0.9934
# Epoch 226: Train Loss 0.1309 | Train Acc 0.9912
# Epoch 227: Train Loss 0.1323 | Train Acc 0.9956
# Epoch 228: Train Loss 0.1328 | Train Acc 0.9912
# Epoch 229: Train Loss 0.1291 | Train Acc 0.9956
# Epoch 230: Train Loss 0.1285 | Train Acc 0.9934
# Epoch 231: Train Loss 0.1263 | Train Acc 0.9934
# Epoch 232: Train Loss 0.1264 | Train Acc 0.9956
# Epoch 233: Train Loss 0.1270 | Train Acc 0.9912
# Epoch 234: Train Loss 0.1271 | Train Acc 0.9934
# Epoch 235: Train Loss 0.1244 | Train Acc 0.9934
# Epoch 236: Train Loss 0.1231 | Train Acc 0.9934
# Epoch 237: Train Loss 0.1230 | Train Acc 0.9934
# Epoch 238: Train Loss 0.1227 | Train Acc 0.9934
# Epoch 239: Train Loss 0.1250 | Train Acc 0.9934
# Epoch 240: Train Loss 0.1250 | Train Acc 0.9934
# Epoch 241: Train Loss 0.1209 | Train Acc 0.9934
# Epoch 242: Train Loss 0.1206 | Train Acc 0.9934
# Epoch 243: Train Loss 0.1332 | Train Acc 0.9890
# Epoch 244: Train Loss 0.1195 | Train Acc 0.9956
# Epoch 245: Train Loss 0.1200 | Train Acc 0.9934
# Epoch 246: Train Loss 0.1213 | Train Acc 0.9956
# Epoch 247: Train Loss 0.1246 | Train Acc 0.9868
# Epoch 248: Train Loss 0.1165 | Train Acc 0.9956
# Epoch 249: Train Loss 0.1166 | Train Acc 0.9956
# Epoch 250: Train Loss 0.1209 | Train Acc 0.9890
# Epoch 251: Train Loss 0.1281 | Train Acc 0.9912
# Epoch 252: Train Loss 0.1198 | Train Acc 0.9912
# Epoch 253: Train Loss 0.1150 | Train Acc 0.9956
# Epoch 254: Train Loss 0.1203 | Train Acc 0.9934
# Epoch 255: Train Loss 0.1329 | Train Acc 0.9868
# Epoch 256: Train Loss 0.1135 | Train Acc 0.9934
# Epoch 257: Train Loss 0.1152 | Train Acc 0.9890
# Epoch 258: Train Loss 0.1422 | Train Acc 0.9803
# Epoch 259: Train Loss 0.1224 | Train Acc 0.9890
# Epoch 260: Train Loss 0.1461 | Train Acc 0.9693
# Epoch 261: Train Loss 0.0984 | Train Acc 0.9956
# Epoch 262: Train Loss 0.0997 | Train Acc 0.9956
# Epoch 263: Train Loss 0.0997 | Train Acc 0.9978
# Epoch 264: Train Loss 0.0980 | Train Acc 0.9978
# Epoch 265: Train Loss 0.0957 | Train Acc 0.9956
# Epoch 266: Train Loss 0.0990 | Train Acc 0.9956
# Epoch 267: Train Loss 0.0968 | Train Acc 0.9978
# Epoch 268: Train Loss 0.0943 | Train Acc 0.9956
# Epoch 269: Train Loss 0.0943 | Train Acc 0.9978
# Epoch 270: Train Loss 0.1025 | Train Acc 0.9956
# Epoch 271: Train Loss 0.0939 | Train Acc 0.9956
# Epoch 272: Train Loss 0.0920 | Train Acc 0.9978
# Epoch 273: Train Loss 0.0915 | Train Acc 0.9956
# Epoch 274: Train Loss 0.0956 | Train Acc 0.9956
# Epoch 275: Train Loss 0.0939 | Train Acc 0.9978
# Epoch 276: Train Loss 0.0908 | Train Acc 0.9978
# Epoch 277: Train Loss 0.0920 | Train Acc 0.9978
# Epoch 278: Train Loss 0.0885 | Train Acc 0.9978
# Epoch 279: Train Loss 0.0880 | Train Acc 0.9978
# Epoch 280: Train Loss 0.1012 | Train Acc 0.9890
# Epoch 281: Train Loss 0.1109 | Train Acc 0.9956
# Epoch 282: Train Loss 0.0919 | Train Acc 0.9934
# Epoch 283: Train Loss 0.0937 | Train Acc 0.9956
# Epoch 284: Train Loss 0.0956 | Train Acc 0.9956
# Epoch 285: Train Loss 0.0910 | Train Acc 0.9846
# Epoch 286: Train Loss 0.1339 | Train Acc 0.9781
# Epoch 287: Train Loss 0.1008 | Train Acc 0.9956
# Epoch 288: Train Loss 0.0955 | Train Acc 0.9890
# Epoch 289: Train Loss 0.0857 | Train Acc 0.9978
# Epoch 290: Train Loss 0.1120 | Train Acc 0.9803
# Epoch 291: Train Loss 0.0991 | Train Acc 0.9912
# Epoch 292: Train Loss 0.0941 | Train Acc 0.9956
# Epoch 293: Train Loss 0.0887 | Train Acc 0.9912
# Epoch 294: Train Loss 0.0790 | Train Acc 0.9934
# Epoch 295: Train Loss 0.0767 | Train Acc 0.9934
# Epoch 296: Train Loss 0.0850 | Train Acc 0.9978
# Epoch 297: Train Loss 0.0799 | Train Acc 0.9912
# Epoch 298: Train Loss 0.0926 | Train Acc 0.9934
# Epoch 299: Train Loss 0.0920 | Train Acc 0.9890
# Epoch 300: Train Loss 0.0755 | Train Acc 0.9912
# Test Loss: 0.4795 | Test Acc: 0.9469
# 64.60176991150442 this is percent 0
# Predicted 0: 64.60%
# Predicted 1: 35.40%

# %%
print(fold_results)
# Out:
# [(0.18556114924068792, 0.9473684210526315), (1.2219494225686056, 0.3684210526315789), (1.224162223046286, 0.37719298245614036), (0.3190265786752366, 0.9473684210526315), (0.47951624351265154, 0.9469026548672567)]

# %%
best_model = models[4]

# %%
print(best_model)
# Out:
# BinaryClassifier(
#   (network): Sequential(
#     (0): Linear(in_features=30, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=18, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=18, out_features=8, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=8, out_features=2, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=2, out_features=1, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=1, out_features=1, bias=True)
#   )
# )
